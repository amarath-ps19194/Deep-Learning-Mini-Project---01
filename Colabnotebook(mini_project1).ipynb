# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cv2
import os

from google.colab import drive
drive.mount('/content/drive')

os.chdir("/content/drive/My Drive/Mini Project 1/")
os.getcwd()

img = image.load_img("Training/PA/pa (1).jpg")

plt.imshow(img)

cv2.imread("Training/PA/pa (1).jpg").shape

train = ImageDataGenerator(rescale = 1/255)

validation = ImageDataGenerator(rescale = 1/255)

train_dataset = train.flow_from_directory('Training/',
                                          target_size = (200,200),
                                          batch_size = 3,
                                          class_mode = 'binary')

validation_dataset = validation.flow_from_directory('Validation/',
                                                   target_size = (200,200),
                                                   batch_size = 3,
                                                   class_mode = 'binary')

train_dataset.class_indices

train_dataset.classes

model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(16,(3,3),activation = 'relu',input_shape = (200,200,3)),
                                   # MaxPooling layer with pool size (2, 2)
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Convolutional layer with 32 filters, each of size (3, 3), and ReLU activation
                                    tf.keras.layers.Conv2D(32,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Convolutional layer with 64 filters, each of size (3, 3), and ReLU activation
                                    tf.keras.layers.Conv2D(64,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Flatten layer to convert 3D feature maps to 1D feature vectors
                                    tf.keras.layers.Flatten(),
                                   # Dense (fully connected) layer with 512 units and ReLU activation
                                    tf.keras.layers.Dense(512,activation = 'relu'),
                                   # Output layer with 1 unit and sigmoid activation for binary classification
                                    tf.keras.layers.Dense(1,activation = 'sigmoid')
                                    ])

model.compile(loss = 'binary_crossentropy',
              optimizer = RMSprop(lr=0.001),
              metrics = ['accuracy'])



model_fit = model.fit(train_dataset,
                      steps_per_epoch = 5,
                      epochs = 30,
                      validation_data = validation_dataset)


validation_dataset.class_indices

dir_path = 'Testing/'

for i in os.listdir(dir_path):
    # Load the image and resize it to the target size
  img = image.load_img(dir_path+ i,target_size=(200,200))
  # Display the image using matplotlib
  plt.imshow(img)
  plt.show()

  # Convert the image to a NumPy array and add an extra dimension
  X = image.img_to_array(img)
  X = np.expand_dims(X,axis = 0)
# Stack the array vertically to create a batch of images
  images = np.vstack([X])
# Make a prediction using the trained model
  val = model.predict(images)
# Check the predicted value and print the corresponding class label
  if val == 0:
    print("This is Letter 'Pa' in Sinhala")
  else:
    print("This is Letter 'Ya' in Sinhala")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 100 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 5/5 [==============================] - 11s 2s/step - loss: 5.5780 - accuracy: 0.6923 - val_loss: 0.7467 - val_accuracy: 0.5000
# Epoch 2/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.8247 - accuracy: 0.4667 - val_loss: 0.6919 - val_accuracy: 0.5000
# Epoch 3/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.7061 - accuracy: 0.5333 - val_loss: 0.6925 - val_accuracy: 0.5000
# Epoch 4/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.7495 - accuracy: 0.5333 - val_loss: 0.6896 - val_accuracy: 0.5000
# Epoch 5/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.8010 - accuracy: 0.6000 - val_loss: 0.7782 - val_accuracy: 0.5000
# Epoch 6/30
# 5/5 [==============================] - 5s 1s/step - loss: 1.0672 - accuracy: 0.6667 - val_loss: 1.6954 - val_accuracy: 0.5000
# Epoch 7/30
# 5/5 [==============================] - 4s 845ms/step - loss: 0.8250 - accuracy: 0.4000 - val_loss: 0.7105 - val_accuracy: 0.5000
# Epoch 8/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.7142 - accuracy: 0.4667 - val_loss: 0.6844 - val_accuracy: 0.5000
# Epoch 9/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.6847 - accuracy: 0.6667 - val_loss: 0.6734 - val_accuracy: 0.5000
# Epoch 10/30
# 5/5 [==============================] - 4s 848ms/step - loss: 0.6686 - accuracy: 0.6667 - val_loss: 0.6756 - val_accuracy: 0.5000
# Epoch 11/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.8157 - accuracy: 0.5385 - val_loss: 0.6803 - val_accuracy: 0.5000
# Epoch 12/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.7708 - accuracy: 0.6923 - val_loss: 0.6479 - val_accuracy: 0.8500
# Epoch 13/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.6530 - accuracy: 0.7333 - val_loss: 0.5643 - val_accuracy: 0.8100
# Epoch 14/30
# 5/5 [==============================] - 4s 829ms/step - loss: 0.6991 - accuracy: 0.6154 - val_loss: 0.5502 - val_accuracy: 0.7800
# Epoch 15/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.4849 - accuracy: 0.8000 - val_loss: 0.4605 - val_accuracy: 0.7700
# Epoch 16/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.5001 - accuracy: 0.6923 - val_loss: 0.6047 - val_accuracy: 0.7000
# Epoch 17/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.5344 - accuracy: 0.8667 - val_loss: 0.3975 - val_accuracy: 0.8100
# Epoch 18/30
# 5/5 [==============================] - 7s 1s/step - loss: 0.0871 - accuracy: 1.0000 - val_loss: 3.3230 - val_accuracy: 0.5000
# Epoch 19/30
# 5/5 [==============================] - 5s 1s/step - loss: 1.3782 - accuracy: 0.7333 - val_loss: 0.5022 - val_accuracy: 0.7400
# Epoch 20/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.5491 - accuracy: 0.6667 - val_loss: 0.4890 - val_accuracy: 0.7700
# Epoch 21/30
# 5/5 [==============================] - 4s 878ms/step - loss: 0.5750 - accuracy: 0.7333 - val_loss: 0.4530 - val_accuracy: 0.7700
# Epoch 22/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.6765 - accuracy: 0.7333 - val_loss: 0.3938 - val_accuracy: 0.8000
# Epoch 23/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.5364 - accuracy: 0.7333 - val_loss: 0.3497 - val_accuracy: 0.8600
# Epoch 24/30
# 5/5 [==============================] - 4s 878ms/step - loss: 0.4829 - accuracy: 0.7333 - val_loss: 0.3193 - val_accuracy: 0.9000
# Epoch 25/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.2597 - accuracy: 0.9333 - val_loss: 0.3802 - val_accuracy: 0.8100
# Epoch 26/30
# 5/5 [==============================] - 4s 878ms/step - loss: 0.4416 - accuracy: 0.7333 - val_loss: 0.2591 - val_accuracy: 0.9100
# Epoch 27/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.4130 - accuracy: 0.8000 - val_loss: 0.2292 - val_accuracy: 0.9400
# Epoch 28/30
# 5/5 [==============================] - 4s 858ms/step - loss: 0.1616 - accuracy: 0.9333 - val_loss: 0.2449 - val_accuracy: 0.9300
# Epoch 29/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.1823 - accuracy: 0.9333 - val_loss: 5.0406 - val_accuracy: 0.5000
# Epoch 30/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.9512 - accuracy: 0.7692 - val_loss: 0.2158 - val_accuracy: 0.9300
# 1/1 [==============================] - 0s 96ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 39ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Pa' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 44ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 53ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 70ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 55ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 60ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 56ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 58ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 53ms/step
# This is Letter 'Pa' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Pa' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Pa' in Sinhala
# 1/1 [==============================] - 0s 39ms/step
# This is Letter 'Pa' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Pa' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Pa' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'Pa' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Pa' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'Pa' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Pa' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 41ms/step
# This is Letter 'Pa' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'Pa' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 38ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Pa' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Pa' in Sinhala
# 1/1 [==============================] - 0s 37ms/step
# This is Letter 'Pa' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Pa' in Sinhala
